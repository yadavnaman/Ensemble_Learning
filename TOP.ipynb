# %% [markdown]
# <a href="https://colab.research.google.com/github/yadavnaman/Ensemble_Learning/blob/master/TOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
# !wget "https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip"
# !unzip 'bank.zip'
# Out:
# --2021-03-26 04:22:49--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 579043 (565K) [application/x-httpd-php]
# Saving to: ‘bank.zip’
#
# bank.zip            100%[===================>] 565.47K  2.17MB/s    in 0.3s
#
# 2021-03-26 04:22:49 (2.17 MB/s) - ‘bank.zip’ saved [579043/579043]
#
# Archive:  bank.zip
#   inflating: bank-full.csv
#   inflating: bank-names.txt
#   inflating: bank.csv

# %%
dataset=pd.read_csv('bank-full.csv',sep=';')
dataset=pd.DataFrame(dataset)

# %%
Y=dataset.iloc[:,-1]
X=dataset.iloc[:,:-1]
X=X.drop(['contact'],axis='columns')
X
# Out:
#        age           job   marital  ... pdays previous  poutcome
# 0       58    management   married  ...    -1        0   unknown
# 1       44    technician    single  ...    -1        0   unknown
# 2       33  entrepreneur   married  ...    -1        0   unknown
# 3       47   blue-collar   married  ...    -1        0   unknown
# 4       33       unknown    single  ...    -1        0   unknown
# ...    ...           ...       ...  ...   ...      ...       ...
# 45206   51    technician   married  ...    -1        0   unknown
# 45207   71       retired  divorced  ...    -1        0   unknown
# 45208   72       retired   married  ...   184        3   success
# 45209   57   blue-collar   married  ...    -1        0   unknown
# 45210   37  entrepreneur   married  ...   188       11     other
#
# [45211 rows x 15 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
enc=OneHotEncoder()
X=pd.get_dummies(X)

# %%
X=pd.DataFrame(X)

# %%
X.head()
# Out:
#    age  balance  day  ...  poutcome_other  poutcome_success  poutcome_unknown
# 0   58     2143    5  ...               0                 0                 1
# 1   44       29    5  ...               0                 0                 1
# 2   33        2    5  ...               0                 0                 1
# 3   47     1506    5  ...               0                 0                 1
# 4   33        1    5  ...               0                 0                 1
#
# [5 rows x 48 columns]

# %%
Y=pd.get_dummies(Y);
Y
# Out:
#        no  yes
# 0       1    0
# 1       1    0
# 2       1    0
# 3       1    0
# 4       1    0
# ...    ..  ...
# 45206   0    1
# 45207   0    1
# 45208   0    1
# 45209   1    0
# 45210   1    0
#
# [45211 rows x 2 columns]

# %%
Y=Y.drop(['no'],axis='columns')
Y
# Out:
#        yes
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 45206    1
# 45207    1
# 45208    1
# 45209    0
# 45210    0
#
# [45211 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
X,X_final,Y,Y_final=train_test_split(X,Y,test_size=0.1)
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25)
SC=StandardScaler()
X_train=SC.fit_transform(X_train)
V1_test,V2_test,Y1_test,Y2_test=train_test_split(X_test,Y_test,test_size=0.33)
v1_test=SC.fit_transform(V1_test)
V2_test=SC.fit_transform(V2_test)

# %%
V1_test.shape[0]
# Out:
# 6815

# %%
from joblib import dump,load
from sklearn .linear_model import LogisticRegression
class Tree1:
  def __init__(self,loss,ind,rows):
    self.left=None
    self.right=None
    self.loss=loss
    self.ind=ind
    self.rows=rows
    self.par=None
    self.var=None
    self.threshold=None
  def fun(self,clf):
    dump(clf,"model"+str(self.ind))
  def load(self):
    return load("model"+str(self.ind))
clf=LogisticRegression().fit(X_train,Y_train)
#clf.score(V1_test,Y1_test)


X_train=pd.DataFrame(X_train)
from sklearn.metrics import log_loss
from queue import Queue
q=Queue(0)
fpr,tpr,threshold=metrics.roc_curve(Y1_test,clf.predict(V1_test))
loss=1-metrics.auc(fpr,tpr)
ind=1
rows=[]
for i in range (X_train.shape[0]):
  rows.append(i)

root=Tree1(loss,ind,rows)
root.fun(clf)
q.put(root)
terminals=[]

while not q.empty():
  print(q.qsize())
  temp=q.get()
  loss_min=temp.loss
  if(len(temp.rows))<100:
    terminals.append(temp)
    continue
  count=0
  for xi in X_train.columns:
    count=count+1
    print(count)
    row1=[]
    row2=[]
    min1=min(X_train.iloc[temp.rows,xi])
    max1=max(X_train.iloc[temp.rows,xi])
    threshold=min1+(max1-min1)/10
    for i in temp.rows:
      if X_train.iloc[i,xi]<threshold :
        row1.append(i)
      else:
        row2.append(i)
    if len(row2)<100 or len(row1)<100:
        continue
    X_train_left=X_train.iloc[row1,:]
    Y_train_left=Y_train.iloc[row1,:]
    X_train_right=X_train.iloc[row2,:]
    Y_train_right=Y_train.iloc[row2,:]
    a=0
    b=0
    for i in range (Y_train_left.shape[0]):
      if(Y_train_left.iloc[i,0]==0):
        a=a+1
      else:
        b=b+1
    if(a==0 or b==0):
      continue
    a=0
    b=0
    for i in range (Y_train_right.shape[0]):
      if(Y_train_right.iloc[i,0]==0):
        a=a+1
      else:
        b=b+1 
    if(a==0 or b==0):
      continue
    clf_left=LogisticRegression().fit(X_train_left, Y_train_left)
    clf_right=LogisticRegression().fit(X_train_right, Y_train_right)
    fpr1,tpr1,threshold1=metrics.roc_curve(Y1_test,clf_left.predict(V1_test))
    fpr2,tpr2,threshold2=metrics.roc_curve(Y1_test,clf_right.predict(V1_test))
    loss1=1-metrics.auc(fpr1,tpr1)
    loss2=1-metrics.auc(fpr2,tpr2)
    if((loss1+loss2)/2)<loss_min :
      temp.var=xi
      loss_min=(loss1+loss2)/2
      temp.threshold=threshold
  if temp.loss==loss_min:
    terminals.append(temp)
    continue
  xi=temp.var
  row1=[]
  row2=[]
  threshold=temp.threshold
  for i in temp.rows:
    if X_train.iloc[i,xi]<threshold :
        row1.append(i)
    else:
        row2.append(i)
  X_train_left=X_train.iloc[row1,:]
  Y_train_left=Y_train.iloc[row1,:]
  X_train_right=X_train.iloc[row2,:]
  Y_train_right=Y_train.iloc[row2,:]
  clf_left=LogisticRegression().fit(X_train_left, Y_train_left)
  clf_right=LogisticRegression().fit(X_train_right, Y_train_right)
  fpr1,tpr1,threshold1=metrics.roc_curve(Y1_test,clf_left.predict(V1_test))
  fpr2,tpr2,threshold2=metrics.roc_curve(Y1_test,clf_right.predict(V1_test)) 
  loss1=1-metrics.auc(fpr1,tpr1)
  loss2=1-metrics.auc(fpr2,tpr2)
  ind=ind+1
  temp.left=Tree1(loss1,ind,row1)
  ind=ind+1
  temp.right=Tree1(loss2,ind,row2)
  q.put(temp.left)
  q.put(temp.right)
  temp.left.fun(clf_left)
  temp.left.par=temp
  temp.right.fun(clf_right)
  temp.right.par=temp
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 1
# 1
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
q1=Queue(0)
q1.put(root)
a=0
for temp in terminals:
  print(len(temp.rows))
  print('\n')
print(a)
# Out:
# 553
#
#
# 245
#
#
# 893
#
#
# 369
#
#
# 728
#
#
# 199
#
#
# 1482
#
#
# 276
#
#
# 507
#
#
# 100
#
#
# 265
#
#
# 133
#
#
# 100
#
#
# 244
#
#
# 216
#
#
# 454
#
#
# 231
#
#
# 212
#
#
# 155
#
#
# 249
#
#
# 1188
#
#
# 286
#
#
# 499
#
#
# 171
#
#
# 169
#
#
# 321
#
#
# 105
#
#
# 116
#
#
# 203
#
#
# 219
#
#
# 285
#
#
# 353
#
#
# 112
#
#
# 6516
#
#
# 105
#
#
# 279
#
#
# 128
#
#
# 141
#
#
# 111
#
#
# 299
#
#
# 292
#
#
# 1191
#
#
# 342
#
#
# 2969
#
#
# 113
#
#
# 254
#
#
# 328
#
#
# 125
#
#
# 186
#
#
# 374
#
#
# 462
#
#
# 203
#
#
# 181
#
#
# 980
#
#
# 150
#
#
# 2568
#
#
# 107
#
#
# 144
#
#
# 224
#
#
# 106
#
#
# 0

# %%
len(terminals)
# Out:
# 60

# %%
dictionary={}
count=0
for terminal in terminals:
  dictionary[terminal.ind]=count
  count=count+1
predictor=[]
for terminal in terminals:
  par=[]
  temp_node=terminal
  while temp_node!=None:
    par.append(temp_node.load())
    temp_node=temp_node.par
  pred=[]
  par.reverse()
  for i in par:
    pred.append(i.predict(V2_test))
  pred=np.transpose(pred)
  pred=pd.DataFrame(pred)
  pred
  clf=LogisticRegression().fit(pred,Y2_test)
  predictor.append(clf)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
'''dataset1=pd.read_csv('bank.csv',sep=';')
dataset1=pd.DataFrame(dataset1)
Y_final=dataset1.iloc[:,-1]
X_final=dataset1.iloc[:,:-1]
X_final=X_final.drop(['contact'],axis='columns')
enc=OneHotEncoder()
X_final=pd.get_dummies(X_final)
X_final=pd.DataFrame(X_final)
Y_final=pd.get_dummies(Y_final);
Y_final=Y_final.drop(['no'],axis='columns')'''
Sc=StandardScaler()
X_final=Sc.fit_transform(X_final)
Y_finalpred=[]

# %%
X_final=pd.DataFrame(X_final)
X_final
# Out:
#             0         1         2   ...        45        46        47
# 0     1.483273 -0.363884  0.876693  ... -0.213988 -0.198246  0.486694
# 1     1.204488  0.072333 -1.402529  ... -0.213988 -0.198246  0.486694
# 2     0.368136 -0.397107  0.396857  ... -0.213988 -0.198246  0.486694
# 3     2.784265  8.780660  0.276898  ...  4.673156 -0.198246 -2.054680
# 4    -0.747000 -0.016264  1.596447  ... -0.213988 -0.198246 -2.054680
# ...        ...       ...       ...  ...       ...       ...       ...
# 4517 -0.468216 -0.308203  0.636775  ... -0.213988 -0.198246 -2.054680
# 4518  1.111560  0.743576  0.996652  ... -0.213988 -0.198246  0.486694
# 4519  0.275208 -0.406029 -1.042651  ... -0.213988 -0.198246 -2.054680
# 4520  0.089352 -0.036568  0.276898  ... -0.213988 -0.198246  0.486694
# 4521 -1.676280 -0.115936  0.396857  ... -0.213988 -0.198246  0.486694
#
# [4522 rows x 48 columns]

# %%
def final_prediction(X):
  temp=root
  final=[]
  clf=temp.load()
  final.append((clf.predict(X)).reshape(-1,1))
  while(temp.left!=None):
    if(X.iloc[0,temp.var]<temp.threshold):
      temp=temp.left
    else:
      temp=temp.right
    clf=temp.load()
    final.append((clf.predict(X)).reshape(-1,1))
  final=np.array(final)
  final=final.reshape(1,final.shape[0])
  return predictor[dictionary[temp.ind]].predict(final)

# %%
for i in range(X_final.shape[0]):
  Y_finalpred.append(final_prediction(X_final.iloc[[i],:]))

from sklearn.metrics import accuracy_score
accuracy_score(Y_final,Y_finalpred)
# Out:
# 0.9080053073861123

# %%
fpr,tpr,_=metrics.roc_curve(Y_final,Y_finalpred)
1-metrics.auc(fpr,tpr)
# Out:
# 0.34609345923389945
